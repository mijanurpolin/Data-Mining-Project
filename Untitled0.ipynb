# %% [markdown]
# <a href="https://colab.research.google.com/github/polinm786/Data-Mining-Project/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models,layers,Sequential
import matplotlib.pyplot as plt
import os ,cv2

# %%
import numpy as np

# %%
datadir='/content/drive/MyDrive/Colab Notebooks/projects data mining/5 types of fish'

# %%
Classes=['1. Telapia','2. Taki','3. Black carp','4. Mrigel','5. Grass carp']

# %%
img_shape=(224,224)

# %%
data=[]
for cat in Classes:
  folder=os.path.join(datadir,cat)
  label=Classes.index(cat)
  for img in os.listdir(folder):
    image=os.path.join(folder,img)
    image_array=cv2.imread(image)
    image_array=cv2.resize(image_array,img_shape)
    data.append([image_array,label])

# %%
import random

# %%
random.shuffle(data)
x=[]
y=[]

# %%
for feature,label in data:
  x.append(feature)
  y.append(label)

# %%
x=np.array(x)
y=np.array(y)

# %%
plt.imshow(cv2.cvtColor(x[8],cv2.COLOR_BGR2RGB))

# %%
x=x/255.0

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
xtrain.shape
# Out:
# (350, 224, 224, 3)

# %%
data_aug=Sequential([
                     layers.experimental.preprocessing.RandomFlip('horizontal',input_shape=(224,224,3)),
                     layers.experimental.preprocessing.RandomRotation(0.1),
                     layers.experimental.preprocessing.RandomZoom(0.1)
                       
])

# %%
cnn=models.Sequential([
                       data_aug,
                       layers.Conv2D(32,3,padding='same',input_shape=(224,224,3),activation='relu'),
                       layers.MaxPool2D(),
                       layers.Conv2D(64,3,padding='same',activation='relu'),
                       layers.MaxPool2D(),
                       layers.Flatten(),
                       layers.Dense(64,activation='relu'),
                       layers.Dense(5)




])
cnn.compile(
    optimizer='adam',
    loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# %%
cnn.fit(xtrain,ytrain,epochs=10)
# Out:
# Epoch 1/10
# 11/11 [==============================] - 26s 2s/step - loss: 6.4905 - accuracy: 0.2200
# Epoch 2/10
# 11/11 [==============================] - 24s 2s/step - loss: 1.5934 - accuracy: 0.2771
# Epoch 3/10
# 11/11 [==============================] - 24s 2s/step - loss: 1.5778 - accuracy: 0.2857
# Epoch 4/10
# 11/11 [==============================] - 24s 2s/step - loss: 1.5477 - accuracy: 0.3543
# Epoch 5/10
# 11/11 [==============================] - 24s 2s/step - loss: 1.5120 - accuracy: 0.3200
# Epoch 6/10
# 11/11 [==============================] - 24s 2s/step - loss: 1.3984 - accuracy: 0.3571
# Epoch 7/10
# 11/11 [==============================] - 24s 2s/step - loss: 1.3139 - accuracy: 0.4457
# Epoch 8/10
# 11/11 [==============================] - 24s 2s/step - loss: 1.2691 - accuracy: 0.4800
# Epoch 9/10
# 11/11 [==============================] - 24s 2s/step - loss: 1.2592 - accuracy: 0.5057
# Epoch 10/10
# ...

# %%
cnn.evaluate(xtest,ytest)
# Out:
# 5/5 [==============================] - 2s 476ms/step - loss: 1.5060 - accuracy: 0.3933
# [1.5060245990753174, 0.3933333456516266]

# %%
from sklearn.metrics import classification_report

# %%
ypred=cnn.predict(xtest)

# %%
ypred_final=[np.argmax(i) for i in ypred]

# %%
ypred_final[:5]
# Out:
# [1, 4, 3, 2, 4]

# %%
print('classification_report\n',classification_report(ytest,ypred_final))
# Out:
# classification_report
#                precision    recall  f1-score   support
#
#            0       0.61      0.37      0.46        30
#            1       0.46      0.31      0.37        35
#            2       0.32      0.43      0.37        28
#            3       0.33      0.38      0.36        26
#            4       0.37      0.48      0.42        31
#
#     accuracy                           0.39       150
#    macro avg       0.42      0.40      0.39       150
# weighted avg       0.42      0.39      0.40       150
